# %%
import pandas as pd
import numpy as np
import random

# %%
lpi = pd.read_csv('/content/International_LPI_Scorecard_Select_Countries_v2.csv')
port = pd.read_csv('/content/US_PortCalls_Time_for_ContainerShips_2023_Select_Countries.csv')
wgi = pd.read_csv('/content/WGI_Select_Countries_2023.csv')
combined_ppi = pd.read_csv('/content/combined_ppi_data.csv')
commodity_prices = pd.read_csv('/content/monthly_world_bank_commodity_prices_1960_2025_v2.csv')
tariff = pd.read_csv('/content/tarriff_database_2025_only_semiconductor_components_v2.csv')

# %% [markdown]
# # Suppliers

# %%
lpi
# Out:
#    country_code  year  customs  infrastructure  international_shipments  \
# 0           AUS  2023      3.7             4.1                      3.1
# 1           BEL  2023      3.9             4.1                      3.8
# 2           BRA  2023      2.9             3.2                      2.9
# 3           CAN  2023      4.0             4.3                      3.6
# 4           CHN  2023      3.3             4.0                      3.6
# 5           FIN  2023      4.0             4.2                      4.1
# 6           FRA  2023      3.7             3.8                      3.7
# 7           DEU  2023      3.9             4.3                      3.7
# 8           HKG  2023      3.8             4.0                      4.0
# 9           IND  2023      3.0             3.2                      3.5
# 10          IDN  2023      2.8             2.9                      3.0
# 11          JPN  2023      3.9             4.2                      3.3
# 12          MYS  2023      3.3             3.6                      3.7
# 13          MEX  2023      2.5             2.8                      2.8
# 14          NLD  2023      3.9             4.2                      3.7
# 15          SGP  2023      4.2             4.6                      4.0
# 16          THA  2023      3.3             3.7                      3.5
# 17          ARE  2023      3.7             4.1                      3.8
# 18          GBR  2023      3.5             3.7                      3.5
# 19          USA  2023      3.7             3.9                      3.4
#
#     logistics_competence  tracking  timeliness
# 0                    3.9       4.1         3.6
# 1                    4.2       4.0         4.2
# 2                    3.3       3.2         3.5
# 3                    4.2       4.1         4.1
# 4                    3.8       3.8         3.7
# 5                    4.2       4.2         4.3
# 6                    3.8       4.0         4.1
# 7                    4.2       4.2         4.1
# 8                    4.0       4.2         4.1
# 9                    3.5       3.4         3.6
# 10                   2.9       3.0         3.3
# 11                   4.1       4.0         4.0
# 12                   3.7       3.7         3.7
# 13                   3.0       3.1         3.5
# 14                   4.2       4.2         4.0
# 15                   4.4       4.4         4.3
# 16                   3.5       3.6         3.5
# 17                   4.0       4.1         4.2
# 18                   3.7       4.0         3.7
# 19                   3.9       4.2         3.8

# %%
port.head()
# Out:
#   country_code  year  median_days_in_port
# 0          AUS  2023               1.4417
# 1          CAN  2023               1.4569
# 2          CHN  2023               0.6049
# 3          FRA  2023               0.8535
# 4          DEU  2023               1.0174

# %%
port
# Out:
#   country_code  year  median_days_in_port
# 0          AUS  2023               1.4417
# 1          CAN  2023               1.4569
# 2          CHN  2023               0.6049
# 3          FRA  2023               0.8535
# 4          DEU  2023               1.0174
# 5          IDN  2023               0.9653
# 6          JPN  2023               0.3500
# 7          SGP  2023               0.8521
# 8          GBR  2023               0.6812

# %%
wgi.head()
# Out:
#   country_code  year  control_of_corruption  government_effectiveness  \
# 0          AUS  2023               1.781205                  1.589880
# 1          BEL  2023               1.336844                  1.037022
# 2          BRA  2023              -0.503643                 -0.546764
# 3          CAN  2023               1.671501                  1.516803
# 4          CHN  2023              -0.005370                  0.679014
#
#    political_stability_and_absence_of_violence/terrorism  regulatory_quality  \
# 0                                           0.917057                1.942206
# 1                                           0.403853                1.168225
# 2                                          -0.408568               -0.296478
# 3                                           0.822421                1.644710
# 4                                          -0.513097               -0.356508
#
#    rule_of_law  voice_and_accountability
# 0     1.523184                  1.506602
# 1     1.295375                  1.325729
# 2    -0.308803                  0.382854
# 3     1.473006                  1.479646
# 4    -0.040130                 -1.504554

# %%
combined_ppi
# Out:
#             date  year  month  ppi_value         series_id  \
# 0     1981-06-01  1981      6      181.0  PCU334413334413P
# 1     1981-07-01  1981      7      180.5  PCU334413334413P
# 2     1981-08-01  1981      8      180.8  PCU334413334413P
# 3     1981-09-01  1981      9      179.5  PCU334413334413P
# 4     1981-10-01  1981     10      180.0  PCU334413334413P
# ...          ...   ...    ...        ...               ...
# 2849  2025-08-01  2025      8       77.0            IZ3344
# 2850  2025-09-01  2025      9       77.0            IZ3344
# 2851  2025-10-01  2025     10       77.4            IZ3344
# 2852  2025-11-01  2025     11       77.8            IZ3344
# 2853  2025-12-01  2025     12       77.7            IZ3344
#
#                                                industry  \
# 0        Semiconductor and related device manufacturing
# 1        Semiconductor and related device manufacturing
# 2        Semiconductor and related device manufacturing
# 3        Semiconductor and related device manufacturing
# 4        Semiconductor and related device manufacturing
# ...                                                 ...
# 2849  Semiconductor and other electronic component m...
# 2850  Semiconductor and other electronic component m...
# 2851  Semiconductor and other electronic component m...
# 2852  Semiconductor and other electronic component m...
# 2853  Semiconductor and other electronic component m...
#
#                                             product source country_code  \
# 0                                  Primary products    BLS          USA
# 1                                  Primary products    BLS          USA
# 2                                  Primary products    BLS          USA
# 3                                  Primary products    BLS          USA
# 4                                  Primary products    BLS          USA
# ...                                             ...    ...          ...
# 2849  Semiconductor and other electronic components   FRED          USA
# 2850  Semiconductor and other electronic components   FRED          USA
# 2851  Semiconductor and other electronic components   FRED          USA
# 2852  Semiconductor and other electronic components   FRED          USA
# 2853  Semiconductor and other electronic components   FRED          USA
#
#       base_year
# 0          1998
# 1          1998
# 2          1998
# 3          1998
# 4          1998
# ...         ...
# 2849       2005
# 2850       2005
# 2851       2005
# 2852       2005
# 2853       2005
#
# [2854 rows x 10 columns]

# %%
countries_with_ppi = combined_ppi.country_code.unique()

# %% [markdown]
# # Defining Countries that can inherit OAC PPI's

# %%
OAC_LIKE = ['MYS', 'THA', 'SGP', 'IDN', 'IND', 'HKG']
# actually represented by OAC

# %%
commodity_prices.head()
# Out:
#          date  year  month commodity_family commodity_variant   unit  \
# 0  1960-01-01  1960      1        Crude oil           average  $/bbl
# 1  1960-02-01  1960      2        Crude oil           average  $/bbl
# 2  1960-03-01  1960      3        Crude oil           average  $/bbl
# 3  1960-04-01  1960      4        Crude oil           average  $/bbl
# 4  1960-05-01  1960      5        Crude oil           average  $/bbl
#
#    nominal_price                 source
# 0           1.63  World Bank Pink Sheet
# 1           1.63  World Bank Pink Sheet
# 2           1.63  World Bank Pink Sheet
# 3           1.63  World Bank Pink Sheet
# 4           1.63  World Bank Pink Sheet

# %%
tariff.head()
# Out:
#        hts8                                  brief_description  \
# 0  84145915  Fans used for cooling microprocessors, telecom...
# 1  84248910  Mechanical appliances for projecting, dispersi...
# 2  84733011  Printed circuit assemblies, not incorporating ...
# 3  84733020  Parts and accessories of the ADP machines of h...
# 4  84734010  Printed circuit assemblies for automatic telle...
#
#    mfn_text_rate_pct how_measured
# 0                0.0           NO
# 1                0.0           NO
# 2                0.0          NaN
# 3                0.0           NO
# 4                0.0           NO

# %% [markdown]
# # Extracting Unique Country Codes

# %%
unique_lpi_countries = set(lpi['country_code'].unique())
unique_port_countries = set(port['country_code'].unique())
unique_wgi_countries = set(wgi['country_code'].unique())
unique_combined_ppi_countries = set(combined_ppi['country_code'].unique())
# The 'tariff' DataFrame does not have a 'country_code' column, so it is excluded from this step.

all_unique_countries = unique_lpi_countries.union(
    unique_port_countries,
    unique_wgi_countries,
    unique_combined_ppi_countries
)

unique_countries = sorted(list(all_unique_countries))
print(f"Total unique countries identified: {len(unique_countries)}")
print(f"Unique countries: {unique_countries}")
# Out:
# Total unique countries identified: 21
# Unique countries: ['ARE', 'AUS', 'BEL', 'BRA', 'CAN', 'CHN', 'DEU', 'FIN', 'FRA', 'GBR', 'HKG', 'IDN', 'IND', 'JPN', 'MEX', 'MYS', 'NLD', 'OAC', 'SGP', 'THA', 'USA']

# %% [markdown]
# # Assigning Countries to Relevance Tiers (based on manufacturing + export capability)
#
# e.g., the US is mostly a CONSUMER, not a supplier.

# %%
# Countries that dominate global semiconductor manufacturing and export capacity.
# Dominate supply
tier_1 = ['CHN', 'JPN', 'SGP', 'HKG', 'MYS', 'THA', 'DEU']

# %%
# strong but not dominant
tier_2 = ['MEX', 'IND', 'CAN', 'FRA', 'GBR', 'AUS', 'IDN', 'NLD', 'USA']

# %%
# low relevance in semiconductor manufacturing
tier_3 = [country for country in unique_countries if country not in tier_1 and country not in tier_2 and country != 'OAC']

# %%
tier_3
# Out:
# ['ARE', 'BEL', 'BRA', 'FIN']

# %% [markdown]
# # Mean Value of Relevant Metrics

# %%
lpi_metrics = ['customs', 'infrastructure', 'international_shipments', 'logistics_competence', 'tracking', 'timeliness']
lpi_baseline = lpi.groupby('country_code')[lpi_metrics].mean()
print("LPI Baseline Metrics:")
print(lpi_baseline.head())
# Out:
# LPI Baseline Metrics:
#               customs  infrastructure  international_shipments  \
# country_code
# ARE               3.7             4.1                      3.8
# AUS               3.7             4.1                      3.1
# BEL               3.9             4.1                      3.8
# BRA               2.9             3.2                      2.9
# CAN               4.0             4.3                      3.6
#
#               logistics_competence  tracking  timeliness
# country_code
# ARE                            4.0       4.1         4.2
# AUS                            3.9       4.1         3.6
# BEL                            4.2       4.0         4.2
# BRA                            3.3       3.2         3.5
# CAN                            4.2       4.1         4.1

# %%
port_metrics = ['median_days_in_port']
port_baseline = port.groupby('country_code')[port_metrics].mean()
print("Port Baseline Metrics:")
print(port_baseline.head())
# Out:
# Port Baseline Metrics:
#               median_days_in_port
# country_code
# AUS                        1.4417
# CAN                        1.4569
# CHN                        0.6049
# DEU                        1.0174
# FRA                        0.8535

# %%
wgi_metrics = ['control_of_corruption', 'government_effectiveness', 'political_stability_and_absence_of_violence/terrorism', 'regulatory_quality', 'rule_of_law', 'voice_and_accountability']
wgi_baseline = wgi.groupby('country_code')[wgi_metrics].mean()
print("WGI Baseline Metrics:")
print(wgi_baseline.head())
# Out:
# WGI Baseline Metrics:
#               control_of_corruption  government_effectiveness  \
# country_code
# ARE                        1.073664                  1.604282
# AUS                        1.781205                  1.589880
# BEL                        1.336844                  1.037022
# BRA                       -0.503643                 -0.546764
# CAN                        1.671501                  1.516803
#
#               political_stability_and_absence_of_violence/terrorism  \
# country_code
# ARE                                                    0.677531
# AUS                                                    0.917057
# BEL                                                    0.403853
# BRA                                                   -0.408568
# CAN                                                    0.822421
#
#               regulatory_quality  rule_of_law  voice_and_accountability
# country_code
# ARE                     1.042391     0.881900                 -1.094941
# AUS                     1.942206     1.523184                  1.506602
# BEL                     1.168225     1.295375                  1.325729
# BRA                    -0.296478    -0.308803                  0.382854
# CAN                     1.644710     1.473006                  1.479646

# %%
combined_ppi.year.unique()
# Out:
# array([1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024,
#        2025, 1976, 1977, 1978, 1979, 1980])

# %% [markdown]
# # Generating Synthetic Supplier Profiles

# %%
combined_baselines = pd.concat([
    lpi_baseline,
    port_baseline,
    wgi_baseline
], axis=1, join='outer')

print("Combined Baselines (first 5 rows):")
print(combined_baselines.head())
# Out:
# Combined Baselines (first 5 rows):
#               customs  infrastructure  international_shipments  \
# country_code
# ARE               3.7             4.1                      3.8
# AUS               3.7             4.1                      3.1
# BEL               3.9             4.1                      3.8
# BRA               2.9             3.2                      2.9
# CAN               4.0             4.3                      3.6
#
#               logistics_competence  tracking  timeliness  median_days_in_port  \
# country_code
# ARE                            4.0       4.1         4.2                  NaN
# AUS                            3.9       4.1         3.6               1.4417
# BEL                            4.2       4.0         4.2                  NaN
# BRA                            3.3       3.2         3.5                  NaN
# CAN                            4.2       4.1         4.1               1.4569
#
#               control_of_corruption  government_effectiveness  \
# country_code
# ARE                        1.073664                  1.604282
# AUS                        1.781205                  1.589880
# BEL                        1.336844                  1.037022
# BRA                       -0.503643                 -0.546764
# CAN                        1.671501                  1.516803
#
#               political_stability_and_absence_of_violence/terrorism  \
# country_code
# ARE                                                    0.677531
# AUS                                                    0.917057
# BEL                                                    0.403853
# BRA                                                   -0.408568
# CAN                                                    0.822421
#
#               regulatory_quality  rule_of_law  voice_and_accountability
# country_code
# ARE                     1.042391     0.881900                 -1.094941
# AUS                     1.942206     1.523184                  1.506602
# BEL                     1.168225     1.295375                  1.325729
# BRA                    -0.296478    -0.308803                  0.382854
# CAN                     1.644710     1.473006                  1.479646

# %% [markdown]
# # Synthetic Supplier Generation

# %%
import random
import pandas as pd # Ensure pandas is imported for pd.isna

random.seed(42)


US_PORT_DWELL_SYNTHETIC = 3.0 # average days foreign suppliers take sitting in US port before being released. Will fix with real data once have
SEMICON_CYCLE_WEEKS = 10 # global average fab+packaging cycle time.

# US Suppliers = No port dwell. No ocean transit. Only domestic logistics. E.g., trucking

synthetic_suppliers = []
supplier_id_counter = 1

# Iterate only through the country codes that are actually present in the combined_baselines DataFrame's index
for country_code in combined_baselines.index:
    country_baseline = combined_baselines.loc[country_code]
    # Generate 1 to n suppliers per country based on relevance in industry
    if country_code in tier_1:
      num_suppliers = random.randint(7,10)
    elif country_code in tier_2:
      num_suppliers = random.randint(2,4)
    else: # tier 3
      num_suppliers = random.randint(1,2)

    for i in range(num_suppliers):
        supplier_id = f"SUP_{country_code}_{supplier_id_counter}"

        # Lead Time Mean: Primarily derived from port_baseline['median_days_in_port'] and lpi_baseline['timeliness'], with randomness.
        # -------------------------
        # ORIGIN PORT DWELL (supplier country i.e., how long product sits in own port before shipping)



        if country_code == 'USA':
          port_lead_time = 0.0
        elif country_code in ['CAN', 'MEX']:
          port_lead_time = 0.0 # land border, not ocean export
        else:
          port_lead_time = country_baseline.get('median_days_in_port', 1) # Default to 1 if NaN
          if pd.isna(port_lead_time):
            port_lead_time = combined_baselines.median_days_in_port.median() * random.uniform(0.9, 1.1)

        lpi_timeliness = country_baseline.get('timeliness', 3.0) # Default to 3 if NaN (placeholder)
        if pd.isna(lpi_timeliness):
            lpi_timeliness = combined_baselines.timeliness.median() * random.uniform(0.9, 1.1) # or some other reasonable default

        # Combine and add randomness
        # A simple model: base lead time is related to port time and inversely related to LPI timeliness
        # Higher LPI timeliness (better score) should mean lower lead time.
        base_lead_time = (port_lead_time * 5 + (5 - lpi_timeliness) * 2) / 2 # Scale and combine
        lead_time_mean = max(4 # minimum 4 weeks
                             , base_lead_time * SEMICON_CYCLE_WEEKS * random.uniform(0.9, 1.1)) # Keeps variation realistic and proportional
        # ------------

        # ---------------
        # U.S. PORT FRICTION (APPLIED ONLY TO FOREIGN SUPPLIERS)
        if country_code == 'USA':
          port_friction = 0.0
        elif country_code in ['CAN', 'MEX']:
          port_friction = random.uniform(0.1, 0.5) # land border friction (hours -> fraction of a day)
        else:
          port_friction = US_PORT_DWELL_SYNTHETIC # full typical U.S. port dwell for ocean freight

        lead_time_mean += port_friction
        # ---------------------


        # Lead Time Variance: A small random percentage of lead_time_mean.
        lead_time_variance = lead_time_mean * random.uniform(0.05, 0.2) # 5% to 20% variance
        # --------------------

        # --- Disruption Probability (WGI + LPI blended) ---

        psat_score = country_baseline.get('political_stability_and_absence_of_violence/terrorism', 0)
        cc_score   = country_baseline.get('control_of_corruption', 0)

        # Normalize WGI (-2.5 to 2.5 → 0 to 1)
        normalized_psat = (psat_score + 2.5) / 5.0
        normalized_cc   = (cc_score + 2.5) / 5.0

        wgi_risk = 1 - ((normalized_psat + normalized_cc) / 2)

        # LPI operational risk (1–5 → 0–1 risk)
        infrastructure = country_baseline.get('infrastructure', 3.0)
        logistics_competence = country_baseline.get('logistics_competence', 3.0)

        normalized_infra = 1 - (infrastructure / 5.0)
        normalized_comp  = 1 - (logistics_competence / 5.0)

        lpi_risk = (normalized_infra + normalized_comp) / 2

        # Blend institutional + operational risk
        disruption_prob_base = 0.6 * wgi_risk + 0.4 * lpi_risk

        # Add proportional noise
        noise = random.uniform(-0.1, 0.1) * disruption_prob_base
        disruption_probability = disruption_prob_base + noise

        # Clamp
        disruption_probability = max(0.01, min(0.99, disruption_probability))
        # ----- End Disruption Probability --------

        # ------------------------
        # Compliance Eligibility: How likely supplier is to meet corporate, regulatory, ethical, and trade-compliance requirements
        # How clean, compliant, low-risk partner is from a governance and regulatory standpoint
        # Directly related to WGI metrics such as 'control_of_corruption','regulatory_quality', 'rule of law', 'political stablity', 'lpi customs' with randomness.
        # --- Compliance Eligibility (WGI + LPI Customs blended) ---

        cc_score   = country_baseline.get('control_of_corruption', 0)
        rq_score   = country_baseline.get('regulatory_quality', 0)
        rol_score  = country_baseline.get('rule_of_law', 0)
        psat_score = country_baseline.get('political_stability_and_absence_of_violence/terrorism', 0)

        customs = country_baseline.get('customs', 3.0)  # LPI Customs (1–5)

        # Normalize WGI (-2.5 → +2.5 mapped to 0–1)
        norm_cc   = (cc_score + 2.5) / 5.0
        norm_rq   = (rq_score + 2.5) / 5.0
        norm_rol  = (rol_score + 2.5) / 5.0
        norm_psav = (psat_score + 2.5) / 5.0

        # Normalize LPI Customs (1–5 → 0–1)
        norm_customs = customs / 5.0

        # Weighted compliance model
        compliance_base = (
          0.40 * norm_cc +
          0.25 * norm_rq +
          0.20 * norm_rol +
          0.05 * norm_psav +
          0.10 * norm_customs
            )

        # Add proportional noise (±5–10%)
        noise = random.uniform(-0.10, 0.10) * compliance_base
        compliance_eligibility = compliance_base + noise

        # Clamp to 5%–95%
        compliance_eligibility = max(0.05, min(0.95, compliance_eligibility))





        # -----------------------

        # --------------
        # --- Logistics Reliability (weighted LPI model) ---

        customs = country_baseline.get('customs', 3.0)
        infrastructure = country_baseline.get('infrastructure', 3.0)
        logistics_competence = country_baseline.get('logistics_competence', 3.0)
        tracking = country_baseline.get('tracking', 3.0)
        timeliness = country_baseline.get('timeliness', 3.0)

        # Weighted average of LPI pillars
        weighted_lpi = (
            0.30 * timeliness +
            0.25 * logistics_competence +
            0.20 * infrastructure +
            0.15 * tracking +
            0.10 * customs
        )

        # Convert 1–5 LPI scale → 0–1 reliability
        base_reliability = weighted_lpi / 5.0

        # Add proportional noise (±5%)
        noise = random.uniform(-0.05, 0.05) * base_reliability
        logistics_reliability = base_reliability + noise

        # Clamp to 10%–99%
        logistics_reliability = max(0.10, min(0.99, logistics_reliability))

        # -----------------






        synthetic_suppliers.append({
            'country_code': country_code,
            'supplier_id': supplier_id,
            'lead_time_mean': lead_time_mean,
            'lead_time_variance': lead_time_variance,
            'disruption_probability': disruption_probability,
            'compliance_eligibility': compliance_eligibility,
            'logistics_reliability': logistics_reliability,
        })
        supplier_id_counter += 1

synthetic_suppliers_df = pd.DataFrame(synthetic_suppliers)

print("Synthetic Supplier Profiles (first 5 rows):")
print(synthetic_suppliers_df.head())
# Out:
# Synthetic Supplier Profiles (first 5 rows):
#   country_code supplier_id  lead_time_mean  lead_time_variance  \
# 0          ARE   SUP_ARE_1       29.081672            2.427785
# 1          AUS   SUP_AUS_2       53.948194            2.954602
# 2          AUS   SUP_AUS_3       53.655471            8.445529
# 3          BEL   SUP_BEL_4       30.632043            5.234186
# 4          BEL   SUP_BEL_5       33.266109            2.126099
#
#    disruption_probability  compliance_eligibility  logistics_reliability
# 0                0.283742                0.728946               0.844884
# 1                0.200381                0.789128               0.779876
# 2                0.226886                0.820285               0.768079
# 3                0.274002                0.725275               0.795612
# 4                0.242300                0.801282               0.832547

# %%
synthetic_suppliers_df
# Out:
#    country_code supplier_id  lead_time_mean  lead_time_variance  \
# 0           ARE   SUP_ARE_1       29.081672            2.427785
# 1           AUS   SUP_AUS_2       53.948194            2.954602
# 2           AUS   SUP_AUS_3       53.655471            8.445529
# 3           BEL   SUP_BEL_4       30.632043            5.234186
# 4           BEL   SUP_BEL_5       33.266109            2.126099
# ..          ...         ...             ...                 ...
# 86          THA  SUP_THA_87       36.172719            4.173442
# 87          THA  SUP_THA_88       36.522238            4.386632
# 88          THA  SUP_THA_89       39.347376            2.127328
# 89          USA  SUP_USA_90       11.424375            1.132189
# 90          USA  SUP_USA_91       11.467816            2.209626
#
#     disruption_probability  compliance_eligibility  logistics_reliability
# 0                 0.283742                0.728946               0.844884
# 1                 0.200381                0.789128               0.779876
# 2                 0.226886                0.820285               0.768079
# 3                 0.274002                0.725275               0.795612
# 4                 0.242300                0.801282               0.832547
# ..                     ...                     ...                    ...
# 86                0.415005                0.475663               0.719665
# 87                0.424040                0.503805               0.673557
# 88                0.471242                0.455950               0.704292
# 89                0.315940                0.713011               0.808574
# 90                0.313827                0.786326               0.776687
#
# [91 rows x 7 columns]

# %%
synthetic_suppliers_df.to_csv('synthetic_suppliers.csv', index=False)

# %% [markdown]
# Only use commodity prices for contextual analysis, not cost computatios of products
#
# e.g., Copper prices rose by x% in 2025, contributing to higher IC component products parts in the PPI
#
# OR
#
# Our procurement can detect upstream commodity risk by monitoring raw material price indices.

# %%
commodity_prices.tail()
# Out:
#             date  year  month commodity_family commodity_variant  unit  \
# 6664  2025-09-01  2025      9           Copper               NaN  $/mt
# 6665  2025-10-01  2025     10           Copper               NaN  $/mt
# 6666  2025-11-01  2025     11           Copper               NaN  $/mt
# 6667  2025-12-01  2025     12           Copper               NaN  $/mt
# 6668  2026-01-01  2026      1           Copper               NaN  $/mt
#
#       nominal_price                 source
# 6664        9983.79  World Bank Pink Sheet
# 6665       10739.91  World Bank Pink Sheet
# 6666       10812.03  World Bank Pink Sheet
# 6667       11785.25  World Bank Pink Sheet
# 6668       13012.00  World Bank Pink Sheet

# %%
commodity_prices.commodity_family.unique()
# Out:
# array(['Crude oil', 'Natural gas', 'Natural gas index', 'Aluminum',
#        'Copper'], dtype=object)
